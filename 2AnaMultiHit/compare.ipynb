// %% [markdown]
// ## 比较两种算法的统计
//
// 1 要求正背面均为一重事件时，能量需匹配，否则丢弃事件
//
// 2 正背面均为一重事件时，全部视为有效事件

// %%
TFile *ipf1 = new TFile("ana_2066_W100_reso.root");
TTree *tree1 = (TTree*)ipf1->Get("tree");
TFile *ipf2 = new TFile("ana_2066_W100_allsingle.root");
TTree *tree2 = (TTree*)ipf2->Get("tree");
TCanvas *c1 = new TCanvas;
// Out:
// Warning in <TClass::Init>: no dictionary for class dets is available

// %%
tree1->Draw("vsifv.e>>h1(2000,0,10000)","vsifv.id==10");
tree2->Draw("vsifv.e>>h2(2000,0,10000)","vsifv.id==10");
TH1D *h1 = (TH1D*)gROOT->FindObject("h1");
TH1D *h2 = (TH1D*)gROOT->FindObject("h2");

// %%
%jsroot on
h1->Draw();
h2->SetLineColor(kRed);
h2->Draw("same");
c1->Draw();
// Out:
// <div id="root_plot_1719235633274"
//      style="width: 696px; height: 472px">
// </div>
// <script>
// if (typeof require !== 'undefined') {
//
//     // All requirements met (we are in jupyter notebooks or we loaded requirejs before).
//     display_root_plot_1719235633274();
//
// } else {
//
//     // We are in jupyterlab, we need to insert requirejs and configure it.
//     // Jupyterlab might be installed in a different base_url so we need to know it.
//     try {
//         var base_url = JSON.parse(document.getElementById('jupyter-config-data').innerHTML).baseUrl;
//     } catch(_) {
//         var base_url = '/';
//     }
//
//     // Try loading a local version of requirejs and fallback to cdn if not possible.
//     requirejs_load(base_url + 'static/components/requirejs/require.js', requirejs_success(base_url), function(){
//         requirejs_load('https://cdnjs.cloudflare.com/ajax/libs/require.js/2.2.0/require.min.js', requirejs_success(base_url), function(){
// ...
