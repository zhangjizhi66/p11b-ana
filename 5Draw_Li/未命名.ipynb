// %%
TFile *ipf = new TFile("ana_5394_W1000.root");
TCanvas *c1 = new TCanvas;
gStyle->SetOptStat(0);
TH1D *h1;
TH2D *h2;

// %%
if (h2) delete h2;
h2 = (TH2D*)ipf->Get("hdeq");
h2->SetTitle("Run 5394");
h2->GetXaxis()->SetRangeUser(0,20000);
h2->GetYaxis()->SetRangeUser(-9500,9500);
h2->GetXaxis()->SetTitle("Invariant Mass / keV");
h2->GetYaxis()->SetTitle("CM Energy Difference / keV");
h2->Draw("colz");
c1->SetLogz();
c1->Draw();

// %%
if (h1) delete h1;
h1 = (TH1D*)ipf->Get("hs");
h1->SetTitle("Run 5394");
h1->GetXaxis()->SetRangeUser(0,20000);
h1->GetXaxis()->SetTitle("Invariant Mass / keV");
h1->GetYaxis()->SetTitle("Count");
h1->Draw("colz");
c1->SetLogy();
c1->Draw();
